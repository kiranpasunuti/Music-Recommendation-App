# %%
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in f:\anacond\lib\site-packages (2.109.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in f:\anacond\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in f:\anacond\lib\site-packages (from google-api-python-client) (2.25.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in f:\anacond\lib\site-packages (from google-api-python-client) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in f:\anacond\lib\site-packages (from google-api-python-client) (2.14.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in f:\anacond\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in f:\anacond\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.61.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in f:\anacond\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in f:\anacond\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in f:\anacond\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in f:\anacond\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in f:\anacond\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in f:\anacond\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in f:\anacond\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anacond\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\anacond\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\anacond\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anacond\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.11.17)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_excel("Song dataset(Final).xlsx")

# %%
data
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0           113999  2hETkH7cOfqmz3LqZDHZf5          CesÃ¡ria Evora
# 1           113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 2           113997  6x8ZfSoqDjuNa5SVP5QjvX          CesÃ¡ria Evora
# 3           113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 4           113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# ...            ...                     ...                     ...
# 113995           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# 113996           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 113997           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 113998           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 113999           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
#
#                                                album_name  \
# 0                                          Miss Perfumado
# 1                                       Change Your World
# 2                                                 Best Of
# 3       #mindfulness - Soft Rain for Mindful Meditatio...
# 4       #mindfulness - Soft Rain for Mindful Meditatio...
# ...                                                   ...
# 113995                                            Hold On
# 113996  Crazy Rich Asians (Original Motion Picture Sou...
# 113997                                     To Begin Again
# 113998                                   Ghost (Acoustic)
# 113999                                             Comedy
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                        Barbincor          22       241826     False
# 1                          Friends          41       283893     False
# 2                   Miss Perfumado          22       271466     False
# 3                 Water Into Light          22       385000     False
# 4              Sleep My Little Boy          21       384999     False
# ...                            ...         ...          ...       ...
# 113995                     Hold On          82       198853     False
# 113996  Can't Help Falling In Love          71       201933     False
# 113997              To Begin Again          57       210826     False
# 113998            Ghost - Acoustic          55       149610     False
# 113999                      Comedy          73       230666     False
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0              0.526  0.4870  ...   -10.204     0       0.0725        0.6810
# 1              0.587  0.5060  ...   -10.889     1       0.0297        0.3810
# 2              0.629  0.3290  ...   -10.895     0       0.0420        0.8670
# 3              0.174  0.1170  ...   -18.318     0       0.0401        0.9940
# 4              0.172  0.2350  ...   -16.393     1       0.0422        0.6400
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
# 113996         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 113997         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 113998         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 113999         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000000    0.0893   0.7080   79.198               4
# 1               0.000000    0.2700   0.4130  135.960               4
# 2               0.000000    0.0839   0.7430  132.378               4
# 3               0.976000    0.1050   0.0350   85.239               4
# 4               0.928000    0.0863   0.0339  125.995               5
# ...                  ...       ...      ...      ...             ...
# 113995          0.000000    0.0829   0.1670  119.949               4
# 113996          0.000071    0.1320   0.1430  181.740               3
# 113997          0.000000    0.1170   0.1200   76.332               4
# 113998          0.000006    0.1010   0.2670   77.489               4
# 113999          0.000001    0.3580   0.7150   87.917               4
#
#         track_genre
# 0       world-music
# 1       world-music
# 2       world-music
# 3       world-music
# 4       world-music
# ...             ...
# 113995     acoustic
# 113996     acoustic
# 113997     acoustic
# 113998     acoustic
# 113999     acoustic
#
# [114000 rows x 21 columns]

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %%
data.shape
# Out:
# (114000, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113951 non-null  object
#  3   album_name        113988 non-null  object
#  4   track_name        113990 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB

# %%
# Missing Values
data.isnull().sum()
# Out:
# Unnamed: 0           0
# track_id             0
# artists             49
# album_name          12
# track_name          10
# popularity           0
# duration_ms          0
# explicit             0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# track_genre          0
# dtype: int64

# %%
# Drop missing values
data.dropna(inplace = True)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
# Drop columns
data.drop(['Unnamed: 0','mode','key'], axis = 1, inplace = True)

# %%
data.sample(10)
# Out:
#                       track_id                             artists  \
# 31159   4zi8jA4hDOXyI2lLCJcu8L                     Teenage Fanclub
# 103671  6TzzPXb9WS63CoziZk3Pz1                  Bassnectar;Seasunz
# 7932    6C253cNnjWuHuMn7b6Sag9   Ricky Rich;A Boogie Wit da Hoodie
# 9188    76NtMPMpA6fuUH4euMYZoD                  Rels B;DELLAFUENTE
# 79037   4Uzt7S2w2FWj4hC0iVlcKU                 When Chai Met Toast
# 26964   6NXIFaZ5a9rtnhF7GAHF0U                           The Verve
# 9940    6zXXw4MXN0yzGndlaOBslP  Antonio JosÃ©;Alejandro FernÃ¡ndez
# 15710   6MWTDw0e1N5z4w8xryd4jn            JubilÃ¤umscast Wien 2012
# 62466   2puCdLnS6sKRdbEabw4bjP                         Wiz Khalifa
# 30903   10LCC2yUHBXPoGLRoOi0w8                 Don Diablo;Zak Abel
#
#                                                album_name  \
# 31159                         Songs From Northern Britain
# 103671                          Underground Communication
# 7932                                    Top Off Snap Hits
# 9188                                    Flakk Daniel's Lp
# 79037                                             Believe
# 26964                                  Hits Pop Rock 90's
# 9940                                         Dulce Balada
# 15710   Elisabeth - Gesamtaufnahme Live - JubilÃ¤umsfa...
# 62466                 Ghetto Superstar - New Rap Classics
# 30903                                      pov: it's 2020
#
#                                      track_name  popularity  duration_ms  \
# 31159                   Take the Long Way Round          20       205266
# 103671                         Select Frequency          16       292920
# 7932                                     Habibi           0       162990
# 9188                               Buenos Genes          72       245190
# 79037                               Who Are You          32       288403
# 26964   Bitter Sweet Symphony - Remastered 2016           1       357266
# 9940                                    Tal Vez           0       214080
# 15710                       Elisabeth, mach auf          27       265560
# 62466                           Bad Ass Bitches           0       118466
# 30903                                       Bad           0       169910
#
#         explicit  danceability  energy  loudness  speechiness  acousticness  \
# 31159      False         0.472   0.774    -8.276       0.0293      0.000023
# 103671     False         0.838   0.660    -7.002       0.2560      0.006950
# 7932        True         0.723   0.545    -6.260       0.0490      0.063100
# 9188        True         0.804   0.535    -8.603       0.1430      0.486000
# 79037      False         0.299   0.720    -6.791       0.0431      0.201000
# 26964      False         0.356   0.917    -6.005       0.0487      0.033600
# 9940       False         0.532   0.692    -5.769       0.0462      0.496000
# 15710      False         0.357   0.327   -13.649       0.0846      0.885000
# 62466       True         0.904   0.601    -5.561       0.1980      0.030500
# 30903       True         0.794   0.774    -4.168       0.0810      0.445000
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 31159           0.021000    0.1240    0.646  123.245               4
# 103671          0.000061    0.0884    0.367  104.996               4
# 7932            0.000000    0.2970    0.341  117.885               4
# 9188            0.000000    0.1080    0.628  151.957               4
# 79037           0.327000    0.1060    0.403   91.581               4
# 26964           0.000000    0.4060    0.523  171.172               4
# 9940            0.000000    0.1490    0.460  151.938               4
# 15710           0.000000    0.6930    0.129  146.443               4
# 62466           0.000000    0.6150    0.761   87.037               4
# 30903           0.010100    0.1720    0.674  123.981               4
#
#               track_genre
# 31159           power-pop
# 103671          breakbeat
# 7932              swedish
# 9188              spanish
# 79037                folk
# 26964               r-n-b
# 9940              spanish
# 15710          show-tunes
# 62466             hip-hop
# 30903   progressive-house

# %%
# Check for duplicates values
data[data.duplicated('track_name') == True]
# Out:
#                       track_id                          artists  \
# 118     1myRTCOm1pPlykQTiwbEMy            Bryan & Katie Torwalt
# 159     17mIn8NhvzkNbzxCukVKdZ  Hillsong Worship;Mi-kaisha Rose
# 164     3eiEcBQ9QBHyDmCwuoQXLZ                 Hillsong Worship
# 173     6Xsayxd27Ez7vcRHAg0Wpt                     Urban Rescue
# 321     4TIL4sLUfgra7SbZgoO9SC            Hillsong Young & Free
# ...                        ...                              ...
# 113994  01MVOl9KtVTNfFiBU9I7dc                     Tyrone Wells
# 113995  5vjLSffimiIP26QG5WcN2K                 Chord Overstreet
# 113996  6lfxq3CG4xtTiEg7opyCyx                     Kina Grannis
# 113998  4qPNDBW1i3p13qLCt0Ki3A                     Ben Woodward
# 113999  5SuOikwiRyPMVoIQDJUgSV                      Gen Hoshino
#
#                                                album_name  \
# 118                    I've Got Good News (Live) [Deluxe]
# 159                               These Same Skies (Live)
# 164                                This Is Our God (Live)
# 173                                            Wild Heart
# 321                   Out Here On A Friday Where It Began
# ...                                                   ...
# 113994                               Days I Will Remember
# 113995                                            Hold On
# 113996  Crazy Rich Asians (Original Motion Picture Sou...
# 113998                                   Ghost (Acoustic)
# 113999                                             Comedy
#
#                           track_name  popularity  duration_ms  explicit  \
# 118                 Good News - Live          23       266632     False
# 159          Never Walk Alone - Live          39       348619     False
# 164                           Healer          39       424906     False
# 173                       Open Hands          44       203320     False
# 321     Song For His Presence - Live          37       470760     False
# ...                              ...         ...          ...       ...
# 113994          Days I Will Remember          58       214240     False
# 113995                       Hold On          82       198853     False
# 113996    Can't Help Falling In Love          71       201933     False
# 113998              Ghost - Acoustic          55       149610     False
# 113999                        Comedy          73       230666     False
#
#         danceability  energy  loudness  speechiness  acousticness  \
# 118            0.473  0.4740    -9.175       0.0558        0.3950
# 159            0.420  0.5530    -8.049       0.0332        0.1410
# 164            0.356  0.6680    -6.695       0.0336        0.0221
# 173            0.598  0.7150    -6.036       0.0449        0.0111
# 321            0.499  0.5310   -10.022       0.0291        0.0106
# ...              ...     ...       ...          ...           ...
# 113994         0.688  0.4810    -8.807       0.1050        0.2890
# 113995         0.618  0.4430    -9.681       0.0526        0.4690
# 113996         0.266  0.0596   -18.515       0.0363        0.9050
# 113998         0.420  0.1660   -17.235       0.0763        0.9240
# 113999         0.676  0.4610    -6.746       0.1430        0.0322
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 118             0.000000    0.1630   0.2510  140.746               4
# 159             0.000000    0.1030   0.2140  143.804               4
# 164             0.000112    0.1480   0.0531   76.964               4
# 173             0.000000    0.2330   0.3190   95.028               4
# 321             0.000000    0.2470   0.1390  104.026               4
# ...                  ...       ...      ...      ...             ...
# 113994          0.000000    0.1890   0.6660   98.017               4
# 113995          0.000000    0.0829   0.1670  119.949               4
# 113996          0.000071    0.1320   0.1430  181.740               3
# 113998          0.000006    0.1010   0.2670   77.489               4
# 113999          0.000001    0.3580   0.7150   87.917               4
#
#         track_genre
# 118     world-music
# 159     world-music
# 164     world-music
# 173     world-music
# 321     world-music
# ...             ...
# 113994     acoustic
# 113995     acoustic
# 113996     acoustic
# 113998     acoustic
# 113999     acoustic
#
# [40371 rows x 18 columns]

# %%
# Remove duplicates
data.drop_duplicates(subset='track_name',keep = 'first',inplace=True)

# %%
data.shape
# Out:
# (73569, 18)

# %%
import re

# %%
def cleaning(text):
    text = re.sub('[^a-zA-Z]', ' ', str(text).lower().strip())
    text = re.sub('@[A-Za-z0-9_]+', '', text)
    text = re.sub('#','',text)
    text = re.sub('RT[\s]+','',text)
    text = re.sub('https?:\/\/\S+', '', text)
    text = re.sub('\n',' ',text)
    
    return text

# %%
data['artists'] = data['artists'].apply(cleaning)
data['album_name'] = data['album_name'].apply(cleaning)
data['track_name'] = data['track_name'].apply(cleaning)

# %%
data[data['loudness'] >= 0]
# Out:
#                       track_id                                  artists  \
# 3833    5sqkarfxe7UejHTlCtHCLS          fear  and loathing in las vegas
# 4129    3q7eDGLKP0MlhqaGEJ3Lg0                 cascada fallen superhero
# 4307    2cfUY5ppstJHmqdUcFgZ5O                                nosferatu
# 26487   2VQ66m1O2NELSZ5d5a4aMQ                   sergio vega  el shaka
# 30095   4Y96sBPDQARk39recOzBo9                               marshmello
# 30994   1gt8YXWknKt4sRNZ6SirVW                        marshmello pritam
# 44300   2RCsqMmOl95kCPGxU1DZec                                  sujatha
# 50086   0Rq66lC98vWUw3ZTwpoiRA                           ging nang boyz
# 50393   7FOeR1X65DEG4KjpVhNC4Z                                   sayuri
# 52716   2pgAa9UFMhUd5jnd6wUYgj             seiko oomori kazunobu mineta
# 54166   19ODdY2U4Wqlv6t04dk54j                                   najand
# 54419   3hB9NQ5Mug7EdxMZqfguj3                                   najand
# 54524   19RrA1s0bwwpTRZMQgF0i2                                   najand
# 54533   58Ozh8RlXaF3Ud2aTW1Ge9                                   najand
# 54662   1VHxmBxtPxLmI5Ffb8W35O                                   najand
# 54720   3zHJa7DWse9WLEZqU0g0MZ                                   najand
# 54774   5rm5Zqktf6v3u9yGj6RR5W                                   najand
# 55399   10hKTZyq2N6iSULhpZXrDd                   jpegmafia denzel curry
# 55896   2EMWP3NJeivpl0Seic7Oqz                                jpegmafia
# 59075   65JuCILa3p5RshhdUkpNV4       toronto is broken bvlvnce zardonic
# 59301   7aJhJdMuMHtkO2JfvRmvVB                                   dither
# 59867   2n33B7iUh4oRF37trcSq3M               dither da mouth of madness
# 60331   5mqzhMuUpvnMfwNz6iepmO     diplo french montana lil pump zhavia
# 65290   3W02UysGQaPosS0RaZ9GvN                          evil activities
# 65348   31Rwwh2kKCxExVeYRlGOWu                           gpf riot shift
# 67228   1CsYouzqkhwqLSz2frDwIA                       the outside agency
# 75159   7K0pkS5lqUkFd9kuY0spiK                            the red pears
# 75259   3hXMVNjjdXnDKg1ixBu7Lj                                  gee tee
# 76173   0JBlB87v8DaQS60V7m3T7V  mc saci gord  o do pc dj th do primeiro
# 76261   0t35f7eKjuLqXfidSEvDL2                           dj bruno prado
# 76309   3AhotTd61YSUaIvPDVkmsf                             dj arthur zl
# 76332   0QcivU8FVJhuXfuyyJl2wA                dj blakes dj vst mc gedai
# 76426   64XhWxwgpjs4OtTgOlBfZt                             dj arthur zl
# 76451   6y3vYl2F0OnUwmKxPF6TA1                                 dj arana
# 76471   14nJ7PTwypy8fbt7hbfQqB             dj blakes mc magrinho delano
# 84019   3svdq1Crgj8IMezbI1K6cO                               subtronics
# 84133   2ZkQDs0kJlNJzdnVgi2j52             dirtyphonics ecraze evilnoiz
# 84625   2mhD6IAZ7oGdRT8bzFI5tF                  freaky shaquille o neal
# 84737   317KO2y39CAzDjpP8djR0k                                     oski
# 86130   2wOnY5bQD1TsDHH382Ybta                                    serum
# 86358   1JWUADVbWUsJPix8A4ihQA                                   kanine
# 86467   2V4i1g632jChClwPLPVQe2                         top cat harley d
# 86480   4umiLE5Jq1dLTX5GmBCQBH                            serum voltage
# 86739   1T6HkH2yp8GCheizVFBv9X                                    a m c
# 86761   1bWm3k2gzhB8DFZYwfljyH                            top cat serum
# 86914   42z4vb1D1vq1PlVSnozbll                    top cat serial killaz
# 86925   2aRWAz05qiQ9j5HgX7xNHC                          noisia burr oak
# 86931   4OoFvP5IoFeNRrfXIwIxEJ                                    a m c
# 86977   3WNzOFBAbi5Cc72223avI7                   dj fresh fox stevenson
# 86980   1gPJ3F2p8rwhlzr1AF58W7                    mefjus camo   krooked
# 96104   4sLrEAfwvFAkaL1kwHmvPC                             free refills
# 96113   4nMGtCN3vBJ5MrdPeuUoSP                             free refills
# 96211   25Ff6JPWUkl786IQeCkcCc                             free refills
# 96409   4LM77KZM8EgPn9nKk7TdT5                             free refills
# 96425   0HfHtjS9S9q4DGVC3uIIRB                          five star hotel
# 103092  3InXaDH9pCnoGG8dkwtXUT         deekline specimen a nick the lot
# 103862  3yqoJ4rc45ep4M0iLa32rC                dub pistols deekline kleu
#
#                                                album_name  \
# 3833                                     feeling of unity
# 4129          everytime we touch  fallen superhero remix
# 4307                                  demonic playgrounds
# 26487                              me gusta estar contigo
# 30095                                              love u
# 30994                                                biba
# 44300                          hits of a r rahman nenjame
# 50086                                                door
# 50393                                     special edition
# 52716                                        re  re  love
# 54166                          in the night of revolution
# 54419                          in the night of revolution
# 54524                          in the night of revolution
# 54533                          in the night of revolution
# 54662                          in the night of revolution
# 54720                          in the night of revolution
# 54774                          in the night of revolution
# 55399                                         bald  remix
# 55896                                    hazard duty pay
# 59075                                               clare
# 59301                                decibel outdoor
# 59867                                       defqon
# 60331   welcome to the party  with french montana   li...
# 65290                                              mental
# 65348                                       broccoli fuck
# 67228                                       defqon
# 75159   we bring anything to the table    except table...
# 75259                                             gee tee
# 76173                            isso    porte de bandido
# 76261                  tipo hariel   sei que e raridade
# 76309                             cocota feia pra caralho
# 76332                                          pura magia
# 76426                    montagem cocota feia pra caralho
# 76451                                         rock pesado
# 76471                                       beat oriental
# 84019                                        scream saver
# 84133                           pantheon  evilnoiz remix
# 84625                                         backbreaker
# 84737                                          diabolical
# 86130                                           hillbilly
# 86358                                        central line
# 86467                       return of the champion deejay
# 86480                                     cricket bat vip
# 86739                                             void lp
# 86761                                          gallist ep
# 86914                       return of the champion deejay
# 86925                                    the resonance iv
# 86931                                              energy
# 86977                     gold dust  fox stevenson remix
# 86980                                            sientelo
# 96104                              raw steak black coffee
# 96113                              raw steak black coffee
# 96211                              raw steak black coffee
# 96409                              raw steak black coffee
# 96425                                           gray data
# 103092                     get lucky  nick the lot remix
# 103862                                              ganja
#
#                                                track_name  popularity  \
# 3833                                          let me hear          61
# 4129          everytime we touch   fallen superhero remix          53
# 4307                                      beat the system          27
# 26487                                          el terr  n          45
# 30095                                              love u          41
# 30994                                                biba          56
# 44300                        mel nattu isai  from  jodi            22
# 50086                                                              31
# 50393                                                              52
# 52716                                        re  re  love          25
# 54166                              preaching for the deaf           0
# 54419                                        embezzlement           0
# 54524                                       been tortured           0
# 54533                                            equality           0
# 54662                          a better world is possible           0
# 54720                                      the corruption           0
# 54774                                  islamic capitalism           0
# 55399                                         bald  remix          49
# 55896                                    hazard duty pay           60
# 59075                           paragons   zardonic remix          32
# 59301                                        beat my drum          11
# 59867                                       veilinghallen          16
# 60331   welcome to the party  with french montana   li...          67
# 65290                                              mental          29
# 65348                                       broccoli fuck          54
# 67228   daze of old   chaotic hostility edit   pandemo...          19
# 75159                                           time bomb          25
# 75259                                   hangin  at caltex          25
# 76173                            isso    porte de bandido          42
# 76261                  tipo hariel   sei que e raridade            44
# 76309                             cocota feia pra caralho          45
# 76332                                          pura magia          45
# 76426                    montagem cocota feia pra caralho          47
# 76451   automotivo das piranha   vem comer minha tchec...          47
# 76471                                       beat oriental          47
# 84019                                        scream saver          51
# 84133                           pantheon   evilnoiz remix          36
# 84625                                         backbreaker          45
# 84737                                          cake shake          48
# 86130                                           hillbilly          16
# 86358                                         steamroller          16
# 86467                       pirate radio   harley d remix          18
# 86480                                   cricket bat   vip          18
# 86739                                            bad news          20
# 86761                               gallist   serum remix          21
# 86914                friend in need   serial killaz remix          26
# 86925                             stigma   burr oak remix          32
# 86931                                               nitro          24
# 86977                     gold dust   fox stevenson remix          57
# 86980                                            sientelo          58
# 96104                                         malfunction          15
# 96113                                            silicone          16
# 96211                                            the mall          16
# 96409                               eternity or something          17
# 96425                                          fate dance          16
# 103092                     get lucky   nick the lot remix          10
# 103862                      ganja   deekline   kleu remix          19
#
#         duration_ms  explicit  danceability  energy  loudness  speechiness  \
# 3833         225546     False         0.175   0.995     1.023       0.2110
# 4129         218587     False         0.610   0.971     0.006       0.1690
# 4307         228373      True         0.719   0.992     0.550       0.3660
# 26487        147520     False         0.834   0.759     0.681       0.0432
# 30095        207887     False         0.532   0.954     0.605       0.0393
# 30994        175721     False         0.587   0.963     0.366       0.0552
# 44300         70885     False         0.638   0.907     1.416       0.0487
# 50086        422960     False         0.212   0.786     0.353       0.0636
# 50393        272906     False         0.492   0.959     0.698       0.0535
# 52716        311146     False         0.428   0.988     0.945       0.0681
# 54166        192407     False         0.211   0.975     1.700       0.1070
# 54419        158940     False         0.125   0.734     0.584       0.0591
# 54524         60056     False         0.173   0.996     0.076       0.1610
# 54533         54205     False         0.167   0.963     0.377       0.0711
# 54662         60056     False         0.244   0.499     1.864       0.0794
# 54720        336666     False         0.159   0.895     0.072       0.0924
# 54774         60056     False         0.149   0.868     3.156       0.0767
# 55399        153127      True         0.721   0.949     0.402       0.3100
# 55896        157169      True         0.615   0.951     0.915       0.1690
# 59075        402758      True         0.426   0.996     0.471       0.4340
# 59301        202124     False         0.619   0.994     0.233       0.4600
# 59867        209333     False         0.592   0.964     0.643       0.1820
# 60331        181720      True         0.618   0.845     0.175       0.1320
# 65290        220219     False         0.489   0.991     0.123       0.2850
# 65348        142397     False         0.711   0.996     0.654       0.4600
# 67228        153600     False         0.631   0.962     1.028       0.1330
# 75159        176065     False         0.442   0.800     2.574       0.0686
# 75259        112222     False         0.168   0.942     0.632       0.0548
# 76173        166153      True         0.917   0.904     0.105       0.2960
# 76261        203076      True         0.951   0.987     1.821       0.3630
# 76309        192075     False         0.843   0.976     0.830       0.2930
# 76332        125884      True         0.702   0.958     1.104       0.4970
# 76426        192075      True         0.843   0.976     0.830       0.2930
# 76451        200020      True         0.758   0.985     1.682       0.4250
# 76471        273897      True         0.675   0.884     0.360       0.0624
# 84019        230400     False         0.644   0.880     0.910       0.2740
# 84133        254896     False         0.480   0.979     0.006       0.1660
# 84625        188607      True         0.416   0.963     0.153       0.1000
# 84737        156000     False         0.652   0.969     0.074       0.3330
# 86130        290657     False         0.687   0.986     0.398       0.5020
# 86358        246860     False         0.763   0.965     0.478       0.3150
# 86467        222068     False         0.671   0.971     0.475       0.2410
# 86480        271542     False         0.658   0.996     0.052       0.0701
# 86739        177931     False         0.772   0.994     0.041       0.1700
# 86761        178285     False         0.710   0.981     0.065       0.0621
# 86914        293485     False         0.724   0.955     0.110       0.2320
# 86925        273488     False         0.550   0.865     0.025       0.0473
# 86931        294078     False         0.529   0.979     0.587       0.1260
# 86977        233103     False         0.543   0.981     0.836       0.0490
# 86980        290742     False         0.528   0.934     0.420       0.1680
# 96104        116804     False         0.384   0.955     1.795       0.0851
# 96113        137127      True         0.420   0.997     0.665       0.2180
# 96211        113741      True         0.504   0.982     1.673       0.2040
# 96409        119625     False         0.638   0.689     0.777       0.0673
# 96425        237000     False         0.310   0.999     4.532       0.3430
# 103092       246942     False         0.738   0.880     0.194       0.2290
# 103862       270171     False         0.790   0.973     0.082       0.1470
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 3833        0.000145          0.000003    0.2140   0.3030  184.066
# 4129        0.064100          0.000004    0.3380   0.4870  150.089
# 4307        0.280000          0.045200    0.1300   0.1180   99.977
# 26487       0.508000          0.000285    0.0649   0.9720   95.851
# 30095       0.095300          0.008280    0.2940   0.7700  141.963
# 30994       0.065600          0.000000    0.2700   0.4910  127.842
# 44300       0.284000          0.000000    0.3680   0.5940  112.972
# 50086       0.000070          0.000000    0.1200   0.4130  115.451
# 50393       0.109000          0.000000    0.0796   0.3490  143.966
# 52716       0.017600          0.000003    0.1580   0.6270  131.983
# 54166       0.155000          0.000256    0.3570   0.0503  131.265
# 54419       0.038200          0.859000    0.3720   0.0468  145.090
# 54524       0.196000          0.733000    0.5590   0.0294  135.125
# 54533       0.107000          0.692000    0.3970   0.0310  106.265
# 54662       0.241000          0.718000    0.8010   0.0347   99.663
# 54720       0.001480          0.735000    0.0870   0.1180   82.219
# 54774       0.191000          0.865000    0.6250   0.0494  136.188
# 55399       0.181000          0.000000    0.6460   0.7050  155.015
# 55896       0.038000          0.000000    0.1820   0.6000  121.575
# 59075       0.000090          0.242000    0.1100   0.1360  175.023
# 59301       0.114000          0.000002    0.2590   0.0734  179.942
# 59867       0.008940          0.004570    0.1690   0.3430  179.969
# 60331       0.114000          0.000000    0.4150   0.4860  171.921
# 65290       0.002910          0.001360    0.3200   0.2400   90.953
# 65348       0.414000          0.000004    0.9240   0.0759  110.128
# 67228       0.003760          0.513000    0.0716   0.1340   99.939
# 75159       0.262000          0.000001    0.6640   0.3690  118.053
# 75259       0.064100          0.969000    0.3280   0.2980  172.527
# 76173       0.521000          0.000000    0.3010   0.7670  130.139
# 76261       0.611000          0.000033    0.1030   0.6740  130.005
# 76309       0.310000          0.000000    0.4390   0.7470  130.043
# 76332       0.001670          0.000000    0.1170   0.4210  129.940
# 76426       0.310000          0.000000    0.4390   0.7470  130.043
# 76451       0.647000          0.000000    0.2430   0.4900  130.924
# 76471       0.069400          0.000000    0.2380   0.4280  130.045
# 84019       0.022500          0.544000    0.5750   0.4150   75.021
# 84133       0.085400          0.000298    0.2670   0.1800  144.774
# 84625       0.005600          0.001100    0.1900   0.0361  111.498
# 84737       0.002110          0.002520    0.3370   0.3610   89.914
# 86130       0.253000          0.001820    0.0527   0.3450  175.329
# 86358       0.001970          0.455000    0.3140   0.3660  174.879
# 86467       0.005190          0.000377    0.3330   0.6000  174.052
# 86480       0.007640          0.899000    0.3770   0.7470   87.484
# 86739       0.000043          0.806000    0.3460   0.5900  173.956
# 86761       0.000783          0.027900    0.3530   0.3920   87.508
# 86914       0.013300          0.000053    0.1140   0.5390  174.990
# 86925       0.008500          0.894000    0.4090   0.1200  171.973
# 86931       0.000065          0.801000    0.4380   0.0735  174.043
# 86977       0.003100          0.001250    0.1510   0.4280  173.998
# 86980       0.003080          0.006140    0.0840   0.4100  174.910
# 96104       0.003120          0.603000    0.0542   0.8880  187.112
# 96113       0.005780          0.626000    0.4240   0.5590  155.861
# 96211       0.001540          0.293000    0.2400   0.9150  153.030
# 96409       0.001580          0.789000    0.0795   0.8910  137.025
# 96425       0.000102          0.945000    0.1480   0.0333  160.040
# 103092      0.001060          0.000830    0.1870   0.4490   87.488
# 103862      0.030000          0.000019    0.2620   0.7590   87.474
#
#         time_signature        track_genre
# 3833                 4             trance
# 4129                 4             techno
# 4307                 3             techno
# 26487                3              r-n-b
# 30095                4  progressive-house
# 30994                4  progressive-house
# 44300                4              malay
# 50086                4             j-rock
# 50393                3             j-rock
# 52716                4             j-idol
# 54166                5            iranian
# 54419                4            iranian
# 54524                4            iranian
# 54533                4            iranian
# 54662                3            iranian
# 54720                4            iranian
# 54774                3            iranian
# 55399                4         industrial
# 55896                4         industrial
# 59075                4                idm
# 59301                4                idm
# 59867                4                idm
# 60331                4              house
# 65290                4           hardcore
# 65348                3           hardcore
# 67228                4              happy
# 75159                4             garage
# 75259                4             garage
# 76173                4               funk
# 76261                4               funk
# 76309                4               funk
# 76332                4               funk
# 76426                4               funk
# 76451                4               funk
# 76471                4               funk
# 84019                4            dubstep
# 84133                4            dubstep
# 84625                4            dubstep
# 84737                4            dubstep
# 86130                4      drum-and-bass
# 86358                4      drum-and-bass
# 86467                4      drum-and-bass
# 86480                4      drum-and-bass
# 86739                4      drum-and-bass
# 86761                4      drum-and-bass
# 86914                4      drum-and-bass
# 86925                4      drum-and-bass
# 86931                4      drum-and-bass
# 86977                4      drum-and-bass
# 86980                4      drum-and-bass
# 96104                4               club
# 96113                4               club
# 96211                4               club
# 96409                4               club
# 96425                4               club
# 103092               4          breakbeat
# 103862               4          breakbeat

# %%
data_numeric = data.select_dtypes(include=['number'])
corr = data_numeric.corr()

# Heatmap
plt.figure(figsize=(10,5))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'time_signature', data=data)
# Out:
# <Axes: xlabel='time_signature', ylabel='count'>

# %%
#number of unique artists
artist_counts = data['artists'].value_counts().head(10)

# %%
#plotting Number of Tracks per Artist
plt.figure(figsize=(15,8))
artist_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Tracks per Artist')
plt.xlabel('Artist')
plt.ylabel('Number of Tracks')
plt.xticks(rotation=45, ha='right') 
plt.show()

# %%
#plotting histogram for the numerical columns
columns=['energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','liveness']

for i in columns:
    plt.figure(figsize=(15, 6))
    plt.hist(data[i], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {i}')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    plt.show()

# %%
#plotting tempo against duration_min with views as size
plt.figure(figsize=(12, 6))
plt.scatter(data['tempo'], data['duration_ms'], s=data['popularity'], alpha=0.5, color = 'blue')
plt.title('Scatter Plot of Tempo vs. Duration (Size by Popularity)')
plt.xlabel('Tempo')
plt.ylabel('Duration (ms)')
plt.show()

# %%
#plotting tempo against duration_min with views as size
plt.figure(figsize=(12, 6))
plt.scatter(data['speechiness'], data['duration_ms'], s=data['popularity'])
plt.title('Scatter Plot of Speechiness vs. Duration (Size by Popularity)')
plt.xlabel('Speechiness')
plt.ylabel('Duration (ms)')
plt.show()

# %%
#plotting loudness against energy 
plt.figure(figsize=(12, 6))
plt.scatter(data['energy'], data['loudness'])
plt.title('Scatter Plot of Energy vs Loudness')
plt.xlabel('Energy')
plt.ylabel('Loudness')
plt.show()

# %%
#plotting acousticness against energy 
plt.figure(figsize=(12, 6))
plt.scatter(data['energy'], data['acousticness'])
plt.title('Scatter Plot of Energy vs Loudness')
plt.xlabel('Energy')
plt.ylabel('Acousticness')
plt.show()

# %%
top_songs = data.nlargest(10, 'popularity')

# %%
plt.figure(figsize=(12, 6))
plt.bar(top_songs['track_name'], top_songs['popularity'], color='skyblue')
plt.title('Top 10 Popular Tracks')
plt.xlabel('Tracks')
plt.ylabel('Popularity')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Connect to Google Cloud Console(Youtube API v3)
# https://console.cloud.google.com/
#
# https://console.cloud.google.com/marketplace/product/google/youtube.googleapis.com?project=lunar-inn-406816

# %%
api_key = 'AIzaSyCqchacThqojFg_9QjVu3tpADud46os85M'

# %%
def create_youtube_api_outputs(playlist_name, df):
    youtube = build('youtube', 'v3', developerKey=api_key)
    search_response = youtube.search().list(
        q=playlist_name,
        part='id,snippet',
        type='video',
        maxResults=10 
    ).execute()

    video_details = []
    for item in search_response['items']:
        video_details.append({
            'title': item['snippet']['title'],
            'videoId': item['id']['videoId'],
            'url': f"https://www.youtube.com/watch?v={item['id']['videoId']}"
        })

    youtube_playlist = pd.DataFrame(video_details)
    return youtube_playlist

# %%
def recommendation_engine(playlist_name, df, num_recommendations=5):
    youtube_playlist = create_youtube_api_outputs(playlist_name, df)
    
    if youtube_playlist.empty:
        print("No matching YouTube videos found for the given playlist.")
        return
    df['combined_features'] = df[['track_name', 'artists', 'popularity', 'track_genre']].astype(str).agg(' '.join, axis=1)
    youtube_playlist['combined_features'] = youtube_playlist['title'].astype(str) + ' Unknown'  # Assuming genre is not available for YouTube videos 
    
    
    df = df[~df['combined_features'].duplicated(keep='first')]  #to eliminate duplicates
    
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(df['combined_features'].tolist() + youtube_playlist['combined_features'].tolist())
    cosine_sim = cosine_similarity(tfidf_matrix[-len(youtube_playlist):], tfidf_matrix[:-len(youtube_playlist)])

    for i in range(len(youtube_playlist)):
        track_indices = np.argsort(cosine_sim[i])[::-1][:num_recommendations]
        unique_tracks = set()

        print(f"\nTop recommendations for {youtube_playlist['title'].iloc[i]}:\n")
        for index, track_index in enumerate(track_indices):

            if track_index < len(df):                       #  #Verifing if the track_index is within the bounds of the DataFrame df.
                track = df.iloc[track_index]                ##Retrieves the track information from the DataFrame using the index.

                if track['track_name'] not in unique_tracks:
                    youtube_url = youtube_playlist['url'].iloc[i] if i < len(youtube_playlist) else "No YouTube URL available"
                    image_url = get_spotify_image_url(track['track_name'], track['artists'])
                    print(f"Track: {track['track_name']}\nPopularity: {track['popularity']}\nArtist: {track['artists']}\nGenre: {track['track_genre']}\nYouTube URL: {youtube_url}\nImage URL: {image_url}\n")
                    unique_tracks.add(track['track_name'])

            else:
                print(f"Index {track_index} is out of bounds for the DataFrame.")

# %% [markdown]
# # Generating Images for the URL's using Spotify API
# https://developer.spotify.com/
#
# https://developer.spotify.com/documentation/web-api

# %%
import requests
def get_spotify_image_url(track_name, artist_name):
    SPOTIFY_CLIENT_ID = '1eadc3aa756843018ebe4ab96af1f149'
    SPOTIFY_CLIENT_SECRET = '2c6a61f2ebd74874b005cad8083abf67'
    access_token = get_spotify_access_token(SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET)
    search_url = f'https://api.spotify.com/v1/search?q={track_name} {artist_name}&type=track'
    headers = {'Authorization': f'Bearer {access_token}'}
    response = requests.get(search_url, headers=headers)
    result = response.json()
    
    if 'tracks' in result and 'items' in result['tracks'] and result['tracks']['items']:
        return result['tracks']['items'][0]['album']['images'][0]['url']    # extracted the image URL from the spotify API response
    else:
        return "No image available"

# %%
def get_spotify_access_token(client_id, client_secret):
    token_url = 'https://accounts.spotify.com/api/token'
    auth = (client_id, client_secret)
    data = {'grant_type': 'client_credentials'}
    response = requests.post(token_url, auth=auth, data=data)
    result = response.json()
    return result.get('access_token', '')

# %%
recommendation_engine('Sleep My Little Boy', data)
# Out:
# Top recommendations for Sleep My Child – Lullaby for Babies to go to Sleep | Infobells:
#
# Track: bella s lullaby
# Popularity: 32
# Artist: sleep baby sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=chWrnmCiU_A
# Image URL: https://i.scdn.co/image/ab67616d0000b2731092da45963c6237ad4a0279
#
# Track: sleep sound for babies   underwater
# Popularity: 36
# Artist: wave sounds for sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=chWrnmCiU_A
# Image URL: https://i.scdn.co/image/ab67616d0000b273854c00388e12346c891b9f18
#
# Track: don   t go to sleep
# Popularity: 60
# Artist: me k
# Genre: sad
# YouTube URL: https://www.youtube.com/watch?v=chWrnmCiU_A
# Image URL: https://i.scdn.co/image/ab67616d0000b2731b791a10b81c8d75ea48a3e2
#
# Track: the best music to put you to sleep
# Popularity: 33
# Artist: binaural beats sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=chWrnmCiU_A
# Image URL: https://i.scdn.co/image/ab67616d0000b2739e16d50a33c7db020781b074
#
# Track: waves to sleep
# Popularity: 33
# Artist: ocean waves for sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=chWrnmCiU_A
# Image URL: https://i.scdn.co/image/ab67616d0000b27330b5074e96040585fd742fcb
#
#
# Top recommendations for Leigha Marina - Go To Sleep Lullaby:
#
# Track: bella s lullaby
# Popularity: 32
# Artist: sleep baby sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=89fAGtjTD3s
# Image URL: https://i.scdn.co/image/ab67616d0000b2731092da45963c6237ad4a0279
#
# Track: don   t go to sleep
# Popularity: 60
# Artist: me k
# Genre: sad
# YouTube URL: https://www.youtube.com/watch?v=89fAGtjTD3s
# Image URL: https://i.scdn.co/image/ab67616d0000b2731b791a10b81c8d75ea48a3e2
#
# Track: sleep in love   music box
# Popularity: 0
# Artist: baby lullaby
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=89fAGtjTD3s
# Image URL: https://i.scdn.co/image/ab67616d0000b273698a738ea9d25836e8ab2fc3
#
# Track: sleep naturally
# Popularity: 34
# Artist: baby sleep lullaby academy
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=89fAGtjTD3s
# Image URL: https://i.scdn.co/image/ab67616d0000b273ba4936805b309f39964c0e29
#
# Track: sleep book   music box
# Popularity: 0
# Artist: baby lullaby
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=89fAGtjTD3s
# Image URL: https://i.scdn.co/image/ab67616d0000b273cece53e8840b5a9635493710
#
#
# Top recommendations for Go To Sleep Little Baby (Lullaby Version) | The Hound + The Fox:
#
# Track: the best baby lullaby music
# Popularity: 33
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=oOg1N2r9pTU
# Image URL: https://i.scdn.co/image/ab67616d0000b273e290e8b6946906a63e4dc04d
#
# Track: baby songs
# Popularity: 32
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=oOg1N2r9pTU
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: baby music
# Popularity: 32
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=oOg1N2r9pTU
# Image URL: https://i.scdn.co/image/ab67616d0000b273e290e8b6946906a63e4dc04d
#
# Track: baby sleep music and lullabies
# Popularity: 35
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=oOg1N2r9pTU
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: piano baby lullabies
# Popularity: 33
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=oOg1N2r9pTU
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
#
# Top recommendations for Sleep, Baby Sleep - Nursery Rhyme with Karaoke:
#
# Track: large industrial air conditioner
# Popularity: 35
# Artist: sleep baby sleep baby sleep through the night sweet baby sleep baby
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=3zhJre6Q4AU
# Image URL: https://i.scdn.co/image/ab67616d0000b273210de5ef9c0197c300809767
#
# Track: canon in d
# Popularity: 40
# Artist: sleep baby sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=3zhJre6Q4AU
# Image URL: https://i.scdn.co/image/ab67616d0000b2731092da45963c6237ad4a0279
#
# Track: bella s lullaby
# Popularity: 32
# Artist: sleep baby sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=3zhJre6Q4AU
# Image URL: https://i.scdn.co/image/ab67616d0000b2731092da45963c6237ad4a0279
#
# Track: nursery rhymes
# Popularity: 36
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=3zhJre6Q4AU
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: shhhh baby shusher for sleep
# Popularity: 66
# Artist: baby sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=3zhJre6Q4AU
# Image URL: https://i.scdn.co/image/ab67616d0000b273ef7d620909f74927ba879178
#
#
# Top recommendations for Go to sleep baby lullaby song to put babies to sleep - soft and relaxing bedtime kids nursery rhymes:
#
# Track: nursery rhymes
# Popularity: 36
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=Abbv4s1j9PE
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: the best music to put you to sleep
# Popularity: 33
# Artist: binaural beats sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=Abbv4s1j9PE
# Image URL: https://i.scdn.co/image/ab67616d0000b2739e16d50a33c7db020781b074
#
# Track: soft piano
# Popularity: 32
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=Abbv4s1j9PE
# Image URL: https://i.scdn.co/image/ab67616d0000b273e290e8b6946906a63e4dc04d
#
# Track: relaxing piano
# Popularity: 33
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=Abbv4s1j9PE
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: soft baby lullabies
# Popularity: 33
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=Abbv4s1j9PE
# Image URL: https://i.scdn.co/image/ab67616d0000b273e290e8b6946906a63e4dc04d
#
#
# Top recommendations for Lullabies For Kids - Sleep Baby +More Nursery Rhymes for Kids:
#
# Track: baby shark
# Popularity: 8
# Artist: afro nursery rhymes
# Genre: kids
# YouTube URL: https://www.youtube.com/watch?v=wr8LX3tsbLQ
# Image URL: https://i.scdn.co/image/ab67616d0000b27340bc65b92d1645c6a0ee6d7a
#
# Track: wheels on the bus go round and round  instrumental
# Popularity: 34
# Artist:  kids nursery rhymes nursery rhymes and kids songs
# Genre: children
# YouTube URL: https://www.youtube.com/watch?v=wr8LX3tsbLQ
# Image URL: https://i.scdn.co/image/ab67616d0000b2739dab2730cf51def37c3f8ca5
#
# Track: happy birthday to you
# Popularity: 8
# Artist: the nursery rhymes superstar
# Genre: kids
# YouTube URL: https://www.youtube.com/watch?v=wr8LX3tsbLQ
# Image URL: https://i.scdn.co/image/ab67616d0000b273a9720647cd7169f1485e44b2
#
# Track: nursery rhymes
# Popularity: 36
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=wr8LX3tsbLQ
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: calming pacific ocean roar to induce healing delta sleep waves  nursery rhymes lullabies effect
# Popularity: 66
# Artist: white noise baby sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=wr8LX3tsbLQ
# Image URL: https://i.scdn.co/image/ab67616d0000b27392283de8621426ca03b8360a
#
#
# Top recommendations for BABY SLEEP 15 MINUTE CHALLENGE - LULLABY SONGS TO PUT A BABY TO SLEEP FAST:
#
# Track: baby songs
# Popularity: 32
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=OoN1hQoMwpY
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: baby sleep music and lullabies
# Popularity: 35
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=OoN1hQoMwpY
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
# Track: baby music
# Popularity: 32
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=OoN1hQoMwpY
# Image URL: https://i.scdn.co/image/ab67616d0000b273e290e8b6946906a63e4dc04d
#
# Track: piano baby lullabies
# Popularity: 33
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=OoN1hQoMwpY
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: the best baby lullaby music
# Popularity: 33
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=OoN1hQoMwpY
# Image URL: https://i.scdn.co/image/ab67616d0000b273e290e8b6946906a63e4dc04d
#
#
# Top recommendations for Baby Sleep Music, Lullaby for Babies To Go To Sleep #020 Mozart for Babies Intelligence Stimulation:
#
# Track: baby music for babies
# Popularity: 32
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=vR2lf8Z0SVo
# Image URL: https://i.scdn.co/image/ab67616d0000b273e290e8b6946906a63e4dc04d
#
# Track: night
# Popularity: 0
# Artist: white noise for babies
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=vR2lf8Z0SVo
# Image URL: https://i.scdn.co/image/ab67616d0000b2730adb4bec0056203ecec87045
#
# Track: sleep sound for babies   underwater
# Popularity: 36
# Artist: wave sounds for sleep
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=vR2lf8Z0SVo
# Image URL: https://i.scdn.co/image/ab67616d0000b273854c00388e12346c891b9f18
#
# Track: steady fan for baby sleep
# Popularity: 34
# Artist: white noise babies
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=vR2lf8Z0SVo
# Image URL: https://i.scdn.co/image/ab67616d0000b27306cdbf142d3a2abbcc888cff
#
# Track: pan
# Popularity: 0
# Artist: white noise for babies
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=vR2lf8Z0SVo
# Image URL: https://i.scdn.co/image/ab67616d0000b27311585046d59475035178c40b
#
#
# Top recommendations for [Wholesome][F4A]You are my good boy(shy)(flirting)(flustered)(sub)[Sleep Aid]:
#
# Track: sleep aid  deep sleep   loopable
# Popularity: 33
# Artist: ocean waves sleep aid
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=XUH7lLmJPNI
# Image URL: https://i.scdn.co/image/ab67616d0000b2738a2729aeb4793098c86db96d
#
# Track: sleep aid  sleep ocean   loopable
# Popularity: 36
# Artist: ocean waves sleep aid
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=XUH7lLmJPNI
# Image URL: https://i.scdn.co/image/ab67616d0000b2738a2729aeb4793098c86db96d
#
# Track: are you happy
# Popularity: 68
# Artist: shy martin
# Genre: swedish
# YouTube URL: https://www.youtube.com/watch?v=XUH7lLmJPNI
# Image URL: https://i.scdn.co/image/ab67616d0000b273f047039273f69d31b3208fa4
#
# Track: good together
# Popularity: 52
# Artist: shy martin
# Genre: swedish
# YouTube URL: https://www.youtube.com/watch?v=XUH7lLmJPNI
# Image URL: https://i.scdn.co/image/ab67616d0000b273826a87a15e288fe8fab2aa1b
#
# Track: come to my aid        remaster
# Popularity: 1
# Artist: simply red
# Genre: soul
# YouTube URL: https://www.youtube.com/watch?v=XUH7lLmJPNI
# Image URL: https://i.scdn.co/image/ab67616d0000b273580a410d9914101d45be0efa
#
#
# Top recommendations for Rockabye baby lullaby song to put babies to sleep - soft and relaxing bedtime kids nursery rhymes:
#
# Track: nursery rhymes
# Popularity: 36
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=7ZWL4Kf4Tjk
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77
#
# Track: baby shark
# Popularity: 8
# Artist: afro nursery rhymes
# Genre: kids
# YouTube URL: https://www.youtube.com/watch?v=7ZWL4Kf4Tjk
# Image URL: https://i.scdn.co/image/ab67616d0000b27340bc65b92d1645c6a0ee6d7a
#
# Track: soft piano
# Popularity: 32
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=7ZWL4Kf4Tjk
# Image URL: https://i.scdn.co/image/ab67616d0000b273e290e8b6946906a63e4dc04d
#
# Track: happy birthday to you
# Popularity: 8
# Artist: the nursery rhymes superstar
# Genre: kids
# YouTube URL: https://www.youtube.com/watch?v=7ZWL4Kf4Tjk
# Image URL: https://i.scdn.co/image/ab67616d0000b273a9720647cd7169f1485e44b2
#
# Track: relaxing piano
# Popularity: 33
# Artist: baby sleep music baby lullaby monarch baby lullaby institute
# Genre: sleep
# YouTube URL: https://www.youtube.com/watch?v=7ZWL4Kf4Tjk
# Image URL: https://i.scdn.co/image/ab67616d0000b2734dcc0883e91a0c71776fac77

# %%
recommendation_engine('Telugu songs', data)
# Out:
# Top recommendations for 2023 Top Telugu Hits | Best of 2023 Telugu Songs | 2023 Telugu Dance Songs | Aditya Music:
#
# Track: buttabomma   telugu
# Popularity: 64
# Artist: armaan malik thaman s
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=nWC68IEZg8g
# Image URL: https://i.scdn.co/image/ab67616d0000b27363118748c712b6ac32c0feec
#
# Track: ay pilla   telugu
# Popularity: 59
# Artist: haricharan pawan ch
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=nWC68IEZg8g
# Image URL: https://i.scdn.co/image/ab67616d0000b2732bc9c9353eb7cd25011c5cb6
#
# Track: allari motha  from  brahmastra  telugu
# Popularity: 53
# Artist: pritam nakash aziz
# Genre: indian
# YouTube URL: https://www.youtube.com/watch?v=nWC68IEZg8g
# Image URL: https://i.scdn.co/image/ab67616d0000b273b5aca35b8db9ca51c8eb2f59
#
# Track: hrudayama  from  major   telugu
# Popularity: 60
# Artist: sricharan pakala sid sriram
# Genre: indie
# YouTube URL: https://www.youtube.com/watch?v=nWC68IEZg8g
# Image URL: https://i.scdn.co/image/ab67616d0000b273f536f0710232b977ba84471e
#
# Track: vikram title track   telugu
# Popularity: 57
# Artist: anirudh ravichander prudhvi chandra
# Genre: hip-hop
# YouTube URL: https://www.youtube.com/watch?v=nWC68IEZg8g
# Image URL: https://i.scdn.co/image/ab67616d0000b27336e9eba0cbd35fc9ba3acf79
#
#
# Top recommendations for Chamkeela Angeelesi - Video Song | Dasara | Nani,Keerthy Suresh | Santhosh Narayanan| Srikanth Odela:
#
# Track: enjoy enjaami   spotify singles  with dhee feat  arivu   santhosh narayanan
# Popularity: 49
# Artist: dj snake dhee arivu santhosh narayanan
# Genre: electronic
# YouTube URL: https://www.youtube.com/watch?v=XeGdY8RoxQY
# Image URL: https://i.scdn.co/image/ab67616d0000b273bc404153ef5f169a39b1deaf
#
# Track: evanda enakku custody
# Popularity: 60
# Artist: santhosh narayanan
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=XeGdY8RoxQY
# Image URL: https://i.scdn.co/image/ab67616d0000b273a792cee66d7f36cbd5fcf41e
#
# Track: poi vazhva
# Popularity: 56
# Artist: santhosh narayanan vijaynarain
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=XeGdY8RoxQY
# Image URL: https://i.scdn.co/image/ab67616d0000b273803e99ee30bb2d8169a3fa57
#
# Track: thenmozhi  from  thiruchitrambalam
# Popularity: 79
# Artist: santhosh narayanan anirudh ravichander
# Genre: pop
# YouTube URL: https://www.youtube.com/watch?v=XeGdY8RoxQY
# Image URL: https://i.scdn.co/image/ab67616d0000b27382a4489bc3e7f3d1372b3350
#
# Track: neruppu da
# Popularity: 56
# Artist: santhosh narayanan arunraja kamaraj
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=XeGdY8RoxQY
# Image URL: https://i.scdn.co/image/ab67616d0000b273293055fbfea4bab8275d16c0
#
#
# Top recommendations for LIVE : BHOGI SPECIAL SONG - GODDESS DHANALAKSHMI DEVI TELUGU DEVOTIONAL SONGS 2024:
#
# Track: the goddess
# Popularity: 26
# Artist: sajanka
# Genre: trance
# YouTube URL: https://www.youtube.com/watch?v=WsJjqhxqREI
# Image URL: https://i.scdn.co/image/ab67616d0000b2736eae024e4ff6bf539761d20f
#
# Track: the alphabet song  abc song
# Popularity: 48
# Artist: kids songs rule
# Genre: children
# YouTube URL: https://www.youtube.com/watch?v=WsJjqhxqREI
# Image URL: https://i.scdn.co/image/ab67616d0000b273e4e04d85fdceb1abe218c848
#
# Track: the great unknown   live
# Popularity: 24
# Artist: the ghost inside
# Genre: metalcore
# YouTube URL: https://www.youtube.com/watch?v=WsJjqhxqREI
# Image URL: https://i.scdn.co/image/ab67616d0000b2730ea7a2fdc35f7fef3b152a8b
#
# Track: p   special
# Popularity: 2
# Artist: lacrim
# Genre: french
# YouTube URL: https://www.youtube.com/watch?v=WsJjqhxqREI
# Image URL: https://i.scdn.co/image/ab67616d0000b2732839de8e42f820d959a08736
#
# Track: goddess
# Popularity: 52
# Artist: krewella nervo raja kumari
# Genre: dubstep
# YouTube URL: https://www.youtube.com/watch?v=WsJjqhxqREI
# Image URL: https://i.scdn.co/image/ab67616d0000b273dadc293ef34032dbb6701e7e
#
#
# Top recommendations for Full Video: Priya Mithunam Song | Adipurush | Prabhas | Ajay Atul,Ramajogayya S | Om Raut:
#
# Track: zingaat
# Popularity: 59
# Artist: ajay atul
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=TPYg7NBo4yY
# Image URL: https://i.scdn.co/image/ab67616d0000b273757a24699f13a78d2d207aa8
#
# Track: deva shree ganesha
# Popularity: 63
# Artist: ajay atul ajay gogavale
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=TPYg7NBo4yY
# Image URL: https://i.scdn.co/image/ab67616d0000b273b22e21de789378f223e1795f
#
# Track: brothers anthem
# Popularity: 59
# Artist: ajay atul vishal dadlani
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=TPYg7NBo4yY
# Image URL: https://i.scdn.co/image/ab67616d0000b273b62efc8fa0cbf9bdd3331e49
#
# Track: chikni chameli
# Popularity: 62
# Artist: ajay atul shreya ghoshal
# Genre: pop-film
# YouTube URL: https://www.youtube.com/watch?v=TPYg7NBo4yY
# Image URL: https://i.scdn.co/image/ab67616d0000b273b22e21de789378f223e1795f
#
# Track: abhi mujh mein kahin
# Popularity: 65
# Artist: ajay atul sonu nigam
# Genre: pop
# YouTube URL: https://www.youtube.com/watch?v=TPYg7NBo4yY
# Image URL: https://i.scdn.co/image/ab67616d0000b273b22e21de789378f223e1795f
#
#
# Top recommendations for Telugu Melody Songs | Heart Touching And Emotional Songs Collection | Volga Videos:
#
# Track: feel bad songs
# Popularity: 27
# Artist: verge collection
# Genre: garage
# YouTube URL: https://www.youtube.com/watch?v=NpmmozxoL9E
# Image URL: https://i.scdn.co/image/ab67616d0000b27339fd9f3e33c8c1c1ee8b1728
